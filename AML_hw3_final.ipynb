# %% [markdown]
# ## 1. Load Data

# %%
import pandas as pd
import numpy as np

df_2015 = pd.read_csv('2015_fuel_data.csv')
df_2016 = pd.read_csv('2016_fuel_data.csv')
df_2017 = pd.read_csv('2017_fuel_data.csv')
df_2018 = pd.read_csv('2018_fuel_data.csv')

# Delete the Null in NP array 
df_2015 = df_2015[pd.isnull(df_2015['Model Year']) == False]
df_2016 = df_2016[pd.isnull(df_2016['Model Year']) == False]
df_2017 = df_2017[pd.isnull(df_2017['Model Year']) == False]
df_2018 = df_2018[pd.isnull(df_2018['Model Year']) == False]

# predicted value
y_2015 = df_2015['Comb Unrd Adj FE - Conventional Fuel']
y_2016 = df_2016['Comb Unrd Adj FE - Conventional Fuel']
y_2017 = df_2017['Comb Unrd Adj FE - Conventional Fuel']
y_2018 = df_2018['Comb Unrd Adj FE - Conventional Fuel']

# features names
features = df_2015.columns.get_values()
# Out:
# 311

# %% [markdown]
# ## 2. Preprocess the data

# %% [markdown]
# ### Remove related features

# %%
# Array with strings to remove
remove_array = ["EPA", "Rating", "FE", "Cost", "Range", "CO2", "Guzzler", "MPG", "Smog", 'Unnamed', 'costs']

# Deciding Which Features to Keep
keep_array = features
remove_indices = []
for i in features: 
    for j in remove_array: 
        if i.find(j) != -1: 
            index = np.where(features==i)
            remove_indices.append(index)
            
keep_array = np.delete(keep_array, remove_indices)

# %% [markdown]
# ### Extract remaining features and seperate by types

# %%
raw_X_2015 = df_2015[keep_array]
raw_X_2016 = df_2016[keep_array]
raw_X_2017 = df_2017[keep_array]
raw_X_2018 = df_2018[keep_array]

# numerical features
float_data = list(raw_X_2015.select_dtypes(include=['float64']).columns)
# categorical features
object_data = list(raw_X_2015.select_dtypes(include=['object']).columns)
# Out:
# (3701, 96)

# %% [markdown]
# ### Merge training data

# %%
X_raw_all = raw_X_2015.append(raw_X_2016).append(raw_X_2017).append(raw_X_2018) # add 2018 as well
Y = y_2015.append(y_2016).append(y_2017)
X_raw = raw_X_2015.append(raw_X_2016).append(raw_X_2017)

# %% [markdown]
# ### Encode categorical data

# %%
def transform_categorical(data_frame, columns): 
    df_new = data_frame[columns]
    return( pd.get_dummies(df_new) )
        
categorical_raw_all = transform_categorical(X_raw_all, object_data)
categorical_raw_train = categorical_raw_all[:3701]
categorical_raw_2018 = categorical_raw_all[3701:]

# %% [markdown]
# ## 3. Feature selection and scale the data

# %%
train_feature = []
totalValidRow = [True] * len(Y)
print('Selected Features:')
for feature in float_data:
    validIndex = pd.notnull(X_raw[feature])
    # select feature with specific percent of valid rows 
    if len(validIndex[validIndex == True]) < 0.4*len(validIndex) or feature in [ '# Batteries']: 
        continue
    totalValidRow = totalValidRow & validIndex
    train_feature.append(feature)
    print(feature)
    #print(np.corrcoef(raw_X_2015[feature][validIndex],y_2015[validIndex]))
print('Number of selected numerical features:', len(train_feature))
print('Total rows to be chosen:', len(totalValidRow[totalValidRow == True]))
# X_raw[train_feature]['Model Year']
index2015to2017 = X_raw_all[train_feature]['Model Year'][X_raw_all[train_feature]['Model Year'] != 2018]
index2018 = X_raw_all[train_feature]['Model Year'][X_raw_all[train_feature]['Model Year'] == 2018]
print(len(index2015to2017), len(index2018))
# Out:
# Selected Features:
# Model Year
# Index (Model Type Index)
# Eng Displ
# # Cyl
# # Gears
# Max Ethanol % - Gasoline
# Intake Valves Per Cyl
# Exhaust Valves Per Cyl
# Carline Class
# Number of selected numerical features: 9
# Total rows to be chosen: 3621
# 3701 1220

# %% [markdown]
# ### Exclude empty row, scale numerical data, merge the data and split train test data

# %% [markdown]
# **Training on 2015-2017 data, test on 2018 data.**

# %%
# training data
X = X_raw[train_feature][totalValidRow]

categorical_X = categorical_raw_train[totalValidRow] # catergorical data
categorical_data = categorical_X.as_matrix()

# scale the numerical data
scaler = StandardScaler()
scaler.fit(X)
X_scaled = scaler.transform(X) # numerical data

# combine the training data
x_combine_train = np.concatenate((X_scaled, categorical_data), axis=1)
y_train = Y[totalValidRow]
print('train data feature shape', x_combine_train.shape)  
print('train predict data shape', y_train.shape)

# extract valid row from test data
totalValidRowTest = [True] * len(y_2018)
for feature in train_feature:
    validIndex = pd.notnull(raw_X_2018[feature])
    totalValidRowTest = totalValidRowTest & validIndex

X_test = raw_X_2018[train_feature][totalValidRowTest]
X_test_scaled = scaler.transform(X_test)
# print('X_test_scaled' ,X_test_scaled.shape)
categorical_X_test = categorical_raw_2018[totalValidRowTest]
categorical_data_test = categorical_X_test.as_matrix()

# combine the test data
x_combine_test = np.concatenate((X_test_scaled, categorical_data_test), axis=1)
y_test = y_2018[totalValidRowTest]
print('test data feature shape', x_combine_test.shape)  
print('test predict data shape', y_test.shape)
# Out:
# train data feature shape (3621, 3316)
# train predict data shape (3621,)
# test data feature shape (1194, 3316)
# test predict data shape (1194,)

# %% [markdown]
# ### Task 1 Linear Models
# Measure performance of a linear model using the provided features with appropriate
# preprocessing.
#
# **With 9 numerical features and 3307 binary features, Ridge regression has the best test score of 0.9568 with the 2018 data.**

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

ridge = Ridge().fit(x_combine_train, y_train)
start = datetime.now()
print('Ridge Regression Validation Score',np.mean(cross_val_score(Ridge(), x_combine_train, y_train, cv=10)))
print('Ridge Regression Test Score', ridge.score(x_combine_test, y_test))
print(datetime.now()-start)
# Out:
# Ridge Regression Validation Score 0.9423918314776418
# Test Score 0.9568685740854399
# 0:00:18.389154

# %% [markdown]
# ### Task 2 Feature Engineering
# Build non-linear features or derived features from the provided column. Try to improve the
# performance of a linear model with these.

# %% [markdown]
# **We chose to build interaction features between the 9 numerical features and the 3307 binary features. Ridge Regression has excellent test score at 0.94965 with the 2018 data.**

# %%
# 9 numerical features interact with 3000 binary features
#ASSUMES 9 categorical features! 

for i in range(0, 9): 
    if i == 0: 
        x_i_train = np.hstack([x_combine_train, x_combine_train[:, i:i+1], x_combine_train[:, 9:]])
        x_i_test = np.hstack([x_combine_test, x_combine_test[:, i:i+1], x_combine_test[:, 9:]])
    elif i > 0: 
        x_temp_train = np.hstack([x_combine_train, x_combine_train[:, i:i+1], x_combine_train[:, 9:]])
        x_temp_test = np.hstack([x_combine_test, x_combine_test[:, i:i+1], x_combine_test[:, 9:]])
        x_i_train = np.concatenate((x_i_train, x_temp_train), axis=1) 
        x_i_test = np.concatenate((x_i_test, x_temp_test), axis=1) 

# print(x_i_train.shape, x_i_test.shape)

# %%
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler
from datetime import datetime

ridge_i = Ridge().fit(x_i_train, y_train)
start = datetime.now()
print('Ridge Regression Validation Score',np.mean(cross_val_score(Ridge(), x_i_train, y_train, cv=10)))
print('Ridge Regression Test Score', ridge_i.score(x_i_test, y_test))
print(datetime.now()-start)

# %% [markdown]
# ### Task 3 Any models
# Use any regression model we discussed (trees, forests, gradient boosting, SVM) to improve
# your result. You can (and probably should) change your preprocessing and feature engineering
# to be suitable for the model. You are not required to try all of these models.

# %%
from xgboost import XGBRegressor
xgb = XGBRegressor()
xgb.fit(x_combine_train, y_train)
print('XGBoost Validation Score:', np.mean(cross_val_score(XGBRegressor(), x_combine_train, y_train)))
print('XGBoost Test Score:', xgb.score(x_combine_test, y_test))
# Out:
# XGBoost Validation Score: 0.933932545004671
# XGBoost Test Score: 0.9326001079507726

# %% [markdown]
# ### Task 4 Feature Selections
# Identify features that are important for your best model. Which features are most influential,
# and which features could be removed without decrease in performance? Does removing
# irrelevant features make your model better?

# %%
import matplotlib.pyplot as plt
# plot coefficients from ridge regression
plt.figure(figsize = (15, 10))
plt.plot(ridge.coef_, 'o', alpha = 0.3)
plt.show()

# %% [markdown]
# ### Find influential features

# %%
# combine feature names
feature_names = train_feature + list(categorical_raw_all)
# extract the most influential features
best_features_index =  abs(ridge.coef_) > 3
plt.figure(figsize = (15, 6))
plt.plot(ridge.coef_[best_features_index], 'ro')
selected_features_names = [name for name, flag in zip(feature_names, best_features_index) if flag == True]
plt.xticks(range(10),selected_features_names, rotation=45)
plt.title('most influencial features')
plt.show()

# %% [markdown]
# ### Find features that have low impact

# %%
bad_features_index =  abs(ridge.coef_) < 0.00005
plt.figure(figsize = (5, 3))
plt.plot(ridge.coef_[bad_features_index], 'bo', alpha = 0.2)
plt.ylim(-0.00002, 0.00002)
#selected_features_names = [name for name, flag in zip(feature_names, bad_features_index) if flag == True]
#plt.xticks(range(len(selected_features_names)),selected_features_names, rotation=45)
plt.title('least influencial features')
plt.show()

# %% [markdown]
# **There are 512 features that have coefficients that are less than 0.00005.**

# %%
print('Least influencial features names:', len(selected_features_names))
for name in selected_features_names:
    print(name)
# Out:
# Least influencial features names: 512
# Mfr Name_Koenigsegg
# Division_Koenigsegg Automotive AG
# Carline_328d
# Carline_328d xDrive
# Carline_328d xDrive Sports Wagon
# Carline_535d
# Carline_535d xDrive
# Carline_540d xDrive
# Carline_640i xDrive Gran Turismo
# Carline_740Ld xDrive
# Carline_812 Superfast
# Carline_911 Turbo S Exclusive
# Carline_A5 Sportback quattro
# Carline_ACCORD 2.0T SPORT/TOURING
# Carline_AMG C 43 4MATIC (convertible)
# Carline_AMG E 63 S 4MATIC (Station Wagon
# Carline_AMG GT (coupe)
# Carline_AMG GT (roadster)
# Carline_AMG GT C (coupe)
# Carline_AMG GT C (roadster)
# Carline_AMG GT R (coupe)
# Carline_AMG GT S (coupe)
# Carline_Agera RS
# Carline_Atlas
# Carline_Atlas 4Motion
# Carline_Aventador S Coupe
# Carline_Aventador S Roadster
# Carline_BRZ tS
# Carline_C 300 4MATIC (convertible)
# Carline_C-HR
# Carline_CAMRY LE/SE
# Carline_CAMRY XLE/XSE
# Carline_CAMRY XSE
# Carline_COOPER CLUBMAN
# Carline_COOPER CLUBMAN ALL4
# Carline_COOPER CONVERTIBLE
# Carline_COOPER COUNTRYMAN
# Carline_COOPER COUNTRYMAN ALL4
# Carline_COOPER HARDTOP 2 DOOR
# Carline_COOPER HARDTOP 4 DOOR
# Carline_COOPER S CLUBMAN
# Carline_COOPER S CLUBMAN ALL4
# Carline_COOPER S CONVERTIBLE
# Carline_COOPER S COUNTRYMAN
# Carline_COOPER S COUNTRYMAN ALL4
# Carline_COOPER S HARDTOP 2 DOOR
# Carline_COOPER S HARDTOP 4 DOOR
# Carline_Cayenne Diesel
# Carline_Chiron
# Carline_Compass 4X2
# Carline_Discovery Sport (286 Hp)
# Carline_Durango SRT AWD
# Carline_E 250 BLUETEC
# Carline_E 250 BLUETEC 4MATIC
# Carline_E 400 4MATIC (convertible)
# Carline_ECOSPORT AWD
# Carline_ECOSPORT FWD
# Carline_ENCLAVE
# Carline_Expedition MAX 2WD
# Carline_Expedition MAX 4WD
# Carline_F-Pace (296 Hp)
# Carline_F150 2WD FFV BASE PAYLOAD LT
# Carline_F150 2WD FFV BASE PAYLOAD LT TIRE
# Carline_F150 4WD FFV BASE PAYLOAD LT
# Carline_F150 5.0L 2WD GVWR>7599 LBS
# Carline_F150 5.0L 4WD GVWR>7599 LBS
# Carline_FORD GT
# Carline_G 550 4x4
# Carline_GL 350 BLUETEC 4MATIC
# Carline_GLE 300 d 4MATIC
# Carline_GLE 350 d 4MATIC
# Carline_GLK 250 BLUETEC 4MATIC
# Carline_GS 300
# Carline_GS 300 F SPORT
# Carline_GTC4Lusso T
# Carline_Grand Cherokee TrackHawk 4x4
# Carline_Huayra
# Carline_IS 300
# Carline_JCW COUNTRYMAN ALL4
# Carline_Jaguar E-Pace
# Carline_Jaguar E-Pace (296 Hp)
# Carline_Kona AWD
# Carline_Kona FWD
# Carline_LC 500
# Carline_LC 500h
# Carline_LS 500
# Carline_LS 500 AWD
# Carline_LS 500h
# Carline_LS 500h AWD
# Carline_M4 DTM Champions Edition
# Carline_M550i xDrive
# Carline_ML 250 BLUETEC 4MATIC
# Carline_Maybach S 650
# Carline_Metris (Cargo Van, LWB)
# Carline_NX 300
# Carline_NX 300 AWD
# Carline_NX 300 AWD F SPORT
# Carline_New Wrangler 4X4
# Carline_New Wrangler Unlimited 4X4
# Carline_Optima S
# Carline_Q50 AWD RED SPORT
# Carline_Q50 RED SPORT
# Carline_Q60 AWD RED SPORT
# Carline_Q60 RED SPORT
# Carline_QUATTROPORTE V8
# Carline_R8 AWD
# Carline_R8 RWD
# Carline_R8 Spyder AWD
# Carline_R8 Spyder RWD
# Carline_RC 300
# Carline_REGAL TOURX  AWD
# Carline_RX 350 L
# Carline_RX 350 L AWD
# Carline_Range Rover Evoque (286 Hp)
# Carline_Range Rover Sport TDV6
# Carline_Range Rover TDV6
# Carline_Range Rover Velar
# Carline_S 450
# Carline_S 450 4MATIC
# Carline_S 560 4MATIC
# Carline_S 560 4MATIC Maybach
# Carline_S5 Sportback
# Carline_Sonata SE
# Carline_Stelvio AWD
# Carline_Stinger AWD
# Carline_Stinger RWD
# Carline_TLX AWD A-SPEC
# Carline_TLX FWD A-SPEC
# Carline_TRAVERSE
# Carline_TT RS
# Carline_Tiguan Limited
# Carline_Tiguan Limited 4Motion
# Carline_V90 AWD
# Carline_V90 FWD
# Carline_WRX STI TYPE RA
# Comments - Mfr Eng Cnfg_For ARMADA 2WD, ARMADA 4WD
# Comments - Mfr Eng Cnfg_For Q50 RED SPORT, Q50 AWD RED SPORT, Q60 RED SPORT, Q60 AWD RED SPORT
# Comments - Mfr Eng Cnfg_For Q50, Q50 AWD, Q60, Q60 AWD
# Comments - Mfr Eng Cnfg_For QX80 2WD
# Comments - Mfr Eng Cnfg_GLS 450 4MATIC,
# Comments - Mfr Eng Cnfg_New Gen2 engine and catalyst system.
# Comments - Mfr Eng Cnfg_New engine, Gen2 and catalyst system.
# Comments - Mfr Eng Cnfg_V12 Bosch 552hp engine config - Rapide S standard
# Comments - Mfr Eng Cnfg_V12 Bosch 580HP engine config - Vanquish S & Zagato
# Comments - Mfr Eng Cnfg_for GT-R (Pure, Track Edition and Premium)
# Cyl Deact Desc_16 - 8 cylinder deactivation capability.
# Cyl Deact Desc_AMG S 63 4MATIC (coupe), AMG S 63 4MATIC (convertible), AMG S 63 4MATIC
# Cyl Deact Desc_CTGE S6 / S7 Deactivation of cylinders 2, 3, 5 and 8 by setting the inlet and exhaust valves to a valve lift of zero (all valves are closed), no fuel injection and no ignition. Deactivation conditions: transmission in 3rd gear or higher, ECT greater than 40C, engine speed 930 to 3500 RPM, vehicle speed greater than 25 kmh
# Cyl Deact Desc_CTGF A8 / A8L Deactivation of cylinders 2, 3, 5 and 8 by setting the inlet and exhaust valves to a valve lift of zero (all valves are closed), no fuel injection and no ignition. Deactivation conditions: transmission in 3rd gear or higher, ECT greater than 40C, engine speed 930 to 3500 RPM, vehicle speed greater than 25 kmh
# Cyl Deact Desc_CWUB / RS7 Deactivation of cylinders 2, 3, 5 and 8 by setting the inlet and exhaust valves to a valve lift of zero (all valves are closed), no fuel injection and no ignition. Deactivation conditions: transmission in 3rd gear or higher, ECT greater than 40C, engine speed 930 to 3500 RPM, vehicle speed greater than 25 kmh
# Cyl Deact Desc_CYCA / Flying Spur V8 S Deactivation of cylinders 2, 3, 5 and 8 by setting the inlet and exhaust valves to a valve lift of zero (all valves are closed), no fuel injection and no ignition. Deactivation conditions: transmission in 3rd gear or higher, ECT greater than 40C, engine speed 930 to 3500 RPM, vehicle speed greater than 25 kmh
# Cyl Deact Desc_DDTA S8 Plus Deactivation of cylinders 2, 3, 5 and 8 by setting the inlet and exhaust valves to a valve lift of zero (all valves are closed), no fuel injection and no ignition. Deactivation conditions: transmission in 3rd gear or higher, ECT greater than 40C, engine speed 930 to 3500 RPM, vehicle speed greater than 25 kmh
# Cyl Deact Desc_S 560 4MATIC,S 560 4MATIC MAYBACH, S 560 4MATIC (coupe), S 560, S 560 (convertible)
# Cyl Deact Desc_Switchable HLA(Hydraulic Lash Adjuster) makes the discrete valve state through oil pressure controlled by OCV(Oil Control Valve). #1 & #4 cylinders are deactivated with Switchable HLA and OCV.
# Var Valve Timing Desc_ALLOWS TIMING OF INTAKE AND EXHAUST VALVES TO BE CHANGED WHILE ENGINE IS IN OPERATION
# Var Valve Timing Desc_Apply CVVT
# Var Valve Timing Desc_CAM PHASING
# Var Valve Timing Desc_Continuously Variable
# Var Valve Timing Desc_ECM controlled,Oil pressure driven.
# Var Valve Timing Desc_Fixed intake camshaft. Variable exhaust camshaft phasing.
# Var Valve Timing Desc_See application.
# Var Valve Timing Desc_Variable Valve Timing and Lift Electronic Control (VTEC) system is applied.
# Var Valve Timing Desc_Variable valve Timing (VTC) and lift Electronic Control (VTEC) system is applied.
# Var Valve Lift Desc_Audi Valve Lift System
# Var Valve Lift Desc_Audi Valve Lift for B-cycle
# Var Valve Lift Desc_Audi Valve System - Exhaust valves only
# Var Valve Lift Desc_CAM PHASER
# Var Valve Lift Desc_Variable Valve Timing and Lift Electronic Control (VTEC) system is applied.
# Var Valve Lift Desc_Variable valve Timing (VTC) and lift Electronic Control (VTEC) system is applied.
# Motor Gen Type, If Other_Permanent magnet AC
# Rated Motor Gen Power (kW)_34, 26, 26
# Rated Motor Gen Power (kW)_38
# Fuel Metering Sys Cd_CRDI
# Fuel Metering Sys Cd_DDI
# Fuel Metering Sys Desc_Common Rail Direct Diesel Injection
# Fuel Metering Sys Desc_Direct Diesel Injection (non-common rail)
# Oil Viscosity_0W-16
# Oil Viscosity_0W-20 VW50800
# Oil Viscosity_0W20 VW50400
# Oil Viscosity_0W30 ACEA C2
# Oil Viscosity_0W30 VW50200 / VW50400
# Oil Viscosity_5W-20 ILSAC GF-5
# Oil Viscosity_5W-30 DC225-11
# Oil Viscosity_5W-50
# Oil Viscosity_5W20 API or ILSAC
# Oil Viscosity_5W20 API or ILSAC GF-4
# Oil Viscosity_5W30 API SM or ILSAC GF-4
# Oil Viscosity_5W30 VW 50700
# Oil Viscosity_5W40 VW 50501
# Oil Viscosity_5W40 VW50200
# Oil Viscosity_DEXTOS 2
# Oil Viscosity_SAE 5W-20 API SM
# Oil Viscosity_SAE 5W30 ACEA A5
# Model Type Desc (MFR entered)_488 Spider
# Model Type Desc (MFR entered)_488 Spider w/S&S
# Model Type Desc (MFR entered)_812 Superfast w/S&S
# Model Type Desc (MFR entered)_A-spec
# Model Type Desc (MFR entered)_AMG E 63 S 4MATIC
# Model Type Desc (MFR entered)_AMG E 63 S 4MATIC (S-W)
# Model Type Desc (MFR entered)_AMG G63
# Model Type Desc (MFR entered)_AMG GLE 43 4MATIC (coupe)
# Model Type Desc (MFR entered)_AMG GLE 63 S (coupe)
# Model Type Desc (MFR entered)_AMG GT (COUPE)
# Model Type Desc (MFR entered)_AMG GT (ROADSTER)
# Model Type Desc (MFR entered)_AMG GT C (coupe)
# Model Type Desc (MFR entered)_AMG GT C (roadster)
# Model Type Desc (MFR entered)_AMG GT R (coupe)
# Model Type Desc (MFR entered)_AMG GT S (COUPE)
# Model Type Desc (MFR entered)_Audi A3 quattro
# Model Type Desc (MFR entered)_C 300 4MATIC
# Model Type Desc (MFR entered)_California T
# Model Type Desc (MFR entered)_California T w/S&S
# Model Type Desc (MFR entered)_Discovery TdV6
# Model Type Desc (MFR entered)_E 250 BLUETEC
# Model Type Desc (MFR entered)_E 250 BLUETEC 4MATIC
# Model Type Desc (MFR entered)_F-Type Convertible
# Model Type Desc (MFR entered)_F-Type Coupe
# Model Type Desc (MFR entered)_F-Type S AWD Convertible
# Model Type Desc (MFR entered)_F-Type S AWD Coupe
# Model Type Desc (MFR entered)_F-Type S Convertible
# Model Type Desc (MFR entered)_F-Type S Coupe
# Model Type Desc (MFR entered)_FIT MT
# Model Type Desc (MFR entered)_GL 350 BLUETEC 4MATIC
# Model Type Desc (MFR entered)_GLE 300 d 4MATIC
# Model Type Desc (MFR entered)_GLE 350 d 4MATIC
# Model Type Desc (MFR entered)_GLK 250 BLUETEC 4MATIC
# Model Type Desc (MFR entered)_GTC4Lusso T w/S&S
# Model Type Desc (MFR entered)_GTC4Lusso w/S&S
# Model Type Desc (MFR entered)_Huracan Coupe RWD
# Model Type Desc (MFR entered)_Huracan Coupe all AWD
# Model Type Desc (MFR entered)_Huracan Spyder RWD
# Model Type Desc (MFR entered)_Huracan Spyder all AWD
# Model Type Desc (MFR entered)_Jaguar E-PACE
# Model Type Desc (MFR entered)_Jaguar F-Pace
# Model Type Desc (MFR entered)_Jaguar XJ
# Model Type Desc (MFR entered)_MDX AWD
# Model Type Desc (MFR entered)_MDX AWD with Idle Stop
# Model Type Desc (MFR entered)_MDX FWD
# Model Type Desc (MFR entered)_MDX FWD with Idle Stop
# Model Type Desc (MFR entered)_ML 250 BLUETEC 4MATIC
# Model Type Desc (MFR entered)_MT (Regular)
# Model Type Desc (MFR entered)_Maybach S 650
# Model Type Desc (MFR entered)_NON STOP-START
# Model Type Desc (MFR entered)_PC0 non ESS
# Model Type Desc (MFR entered)_Range Rover Evoque
# Model Type Desc (MFR entered)_Range Rover Evoque Convertible
# Model Type Desc (MFR entered)_Range Rover Sport TdV6
# Model Type Desc (MFR entered)_Range Rover TdV6
# Model Type Desc (MFR entered)_Range Rover Velar
# Model Type Desc (MFR entered)_S 560 4MATIC
# Model Type Desc (MFR entered)_S 560 4MATIC Maybach
# Model Type Desc (MFR entered)_SLC 300
# Model Type Desc (MFR entered)_Select Shift
# Model Type Desc (MFR entered)_TT Roadster quattro
# Model Type Desc (MFR entered)_Velar
# Model Type Desc (MFR entered)_XE 25t
# Model Type Desc (MFR entered)_XE 25t AWD
# Model Type Desc (MFR entered)_XE 30t AWD
# Model Type Desc (MFR entered)_XE 30t RWD
# Model Type Desc (MFR entered)_XE RWD
# Model Type Desc (MFR entered)_XF 25t
# Model Type Desc (MFR entered)_XF 25t AWD
# Model Type Desc (MFR entered)_XF 30t AWD
# Model Type Desc (MFR entered)_XF 30t RWD
# Model Type Desc (MFR entered)_XF AWD
# Model Type Desc (MFR entered)_XF RWD
# Model Type Desc (MFR entered)_XF Sportbrake AWD
# Model Type Desc (MFR entered)_XJL AWD

# %% [markdown]
# ### Remove the features that are not influential and retrain the model

# %%
good_train_data = x_combine_train[:,~bad_features_index]
good_test_data = x_combine_test[:,~bad_features_index]
ridge = Ridge().fit(good_train_data, y_train)
start = datetime.now()
print('Ridge regression validation score after removing trivial data',np.mean(cross_val_score(Ridge(), good_train_data, y_train, cv=10)))
print('Ridge regression test score after removing trivial data', ridge.score(good_test_data, y_test))
print(datetime.now()-start)
# Out:
# Ridge regression validation score after removing trival data 0.9423982862037972
# Ridge regression test score after removing trival data 0.956868573333989
# 0:00:12.866290

# %% [markdown]
# - The orginial ridge regression model has validation score of 0.9423918314776418 and test score of 0.9568685740854399, which is about the same as the results above.
# - **So we can see that remove the trivial data doesn't necessarily improve the result.**
